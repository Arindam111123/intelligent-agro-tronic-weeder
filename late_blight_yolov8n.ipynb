# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-a110d8f1-2a06-4557-bca2-b1d061c6d0e6" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-a110d8f1-2a06-4557-bca2-b1d061c6d0e6">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import zipfile

with zipfile.ZipFile("/content/detect.zip", 'r') as zip_ref:
    zip_ref.extractall("/content/")

# %%
import torch
print(torch.cuda.is_available())
# Out:
# True

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install ultralytics #for Yolov8n
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 83.0 MB/s eta 0:00:00
# ...

# %%
# !cp -r /content/drive/MyDrive/detect /content/

# %%
#Yolov8n Training
from ultralytics import YOLO

model = YOLO("yolov8n.pt")

model.train(
    data="/content/detect/data.yaml",
    epochs=50,
    imgsz=512
)
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# ...
# Ultralytics 8.4.41 🚀 Python-3.12.13 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# ...

# %%
#Yolov8n Metrics
from ultralytics import YOLO

model = YOLO("/content/runs/detect/train/weights/best.pt")

metrics = model.val()

print("Precision:", metrics.box.p)
print("Recall:", metrics.box.r)
print("mAP@0.5:", metrics.box.map50)
print("mAP@0.5:0.95:", metrics.box.map)
# Out:
# Ultralytics 8.4.41 🚀 Python-3.12.13 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# Model summary (fused): 73 layers, 3,006,038 parameters, 0 gradients, 8.1 GFLOPs
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 657.2±405.7 MB/s, size: 13.6 KB)
# val: Scanning /content/detect/labels/val.cache... 528 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 528/528 158.2Mit/s 0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 33/33 5.8it/s 5.7s
#                    all        528       1058      0.789      0.676      0.707      0.572
#           Healthy_Leaf        255        262      0.914      0.992      0.994       0.95
#            Late_Blight        273        796      0.663      0.359      0.421      0.194
# Speed: 1.3ms preprocess, 2.6ms inference, 0.0ms loss, 2.0ms postprocess per image
# Results saved to /content/runs/detect/val-2
# Precision: [    0.91424     0.66292]
# Recall: [    0.99237      0.3593]
# ...

# %%
# Clone YOLOv5 repo
# !git clone https://github.com/ultralytics/yolov5
# %cd yolov5

# Install dependencies
# !pip install -r requirements.txt
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 17924, done.
# remote: Counting objects: 100% (99/99), done.
# remote: Compressing objects: 100% (51/51), done.
# remote: Total 17924 (delta 80), reused 48 (delta 48), pack-reused 17825 (from 2)
# Receiving objects: 100% (17924/17924), 17.04 MiB | 19.87 MiB/s, done.
# Resolving deltas: 100% (12211/12211), done.
# /content/yolov5
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 131.6/131.6 kB 15.4 MB/s eta 0:00:00
# ...
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 2.5.0
#     Uninstalling urllib3-2.5.0:
#       Successfully uninstalled urllib3-2.5.0
# ...

# %%
data = "/content/detect/data.yaml" #For Yolov5n .yaml File

# %%
#Yolov5n Training
# !python train.py \
  --img 512 \
  --batch 16 \
  --epochs 50 \
  --data /content/detect/data.yaml \
  --weights yolov5n.pt \
  --device 0 \
  --name yolov5n_blight
# Out:
# Streaming output truncated to the last 5000 lines.
#   with torch.cuda.amp.autocast(amp):
#       38/49      1.44G    0.04851    0.01583  0.0002326         36        512:  80% 176/220 [01:02<00:11,  3.81it/s]/content/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       38/49      1.44G    0.04854    0.01586  0.0002317         49        512:  80% 177/220 [01:03<00:15,  2.85it/s]/content/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       38/49      1.44G    0.04853    0.01587   0.000231         47        512:  81% 178/220 [01:03<00:12,  3.38it/s]/content/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
# ...

# %%
#Yolov5n Metrics
# !python val.py \
  --weights runs/train/yolov5n_blight/weights/best.pt \
  --data /content/detect/data.yaml \
  --img 512 \
  --device 0
# Out:
# val: data=/content/detect/data.yaml, weights=['runs/train/yolov5n_blight/weights/best.pt'], batch_size=32, imgsz=512, conf_thres=0.001, iou_thres=0.6, max_det=300, task=val, device=0, workers=8, single_cls=False, augment=False, verbose=False, save_txt=False, save_hybrid=False, save_conf=False, save_json=False, project=runs/val, name=exp, exist_ok=False, half=False, dnn=False
# YOLOv5 🚀 v7.0-476-g66554d2f Python-3.12.13 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
#
# Fusing layers...
# Model summary: 157 layers, 1761871 parameters, 0 gradients, 4.1 GFLOPs
# val: Scanning /content/detect/labels/val.cache... 528 images, 0 backgrounds, 0 corrupt: 100% 528/528 [00:00<?, ?it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 17/17 [00:07<00:00,  2.23it/s]
#                    all        528       1058      0.791      0.693      0.703      0.541
#           Healthy_Leaf        528        262       0.94      0.992      0.994      0.906
# ...

# %%
#Fast RCCN

# ================================
# 1. Install dependencies
# ================================
# !pip install pycocotools

# ================================
# 2. Imports
# ================================
import torch
import torchvision
from torchvision.datasets import CocoDetection
from torchvision.transforms import functional as F
from torch.utils.data import DataLoader
import torch.optim as optim

# ================================
# 3. Custom Dataset (FIXED)
# ================================
class CustomCocoDataset(CocoDetection):
    def __getitem__(self, idx):
        img, target = super().__getitem__(idx)

        boxes = []
        labels = []

        for obj in target:
            xmin, ymin, w, h = obj['bbox']
            boxes.append([xmin, ymin, xmin + w, ymin + h])
            labels.append(obj['category_id'] + 1)
        # 🚨 Skip images with NO annotations (negative images)
        if len(boxes) == 0:
            return None

        boxes = torch.as_tensor(boxes, dtype=torch.float32)
        labels = torch.as_tensor(labels, dtype=torch.int64)

        target = {
            "boxes": boxes,
            "labels": labels
        }

        img = F.to_tensor(img)
        return img, target

# ================================
# 4. Collate Function (FIXED)
# ================================
def collate_fn(batch):
    batch = [b for b in batch if b is not None]  # remove empty samples
    return tuple(zip(*batch))

# ================================
# 5. Load Dataset
# ================================
train_dataset = CustomCocoDataset(
    root="/content/detect/images/train",
    annFile="/content/detect/coco_train.json"
)

val_dataset = CustomCocoDataset(
    root="/content/detect/images/val",
    annFile="/content/detect/coco_val.json"
)

train_loader = DataLoader(
    train_dataset,
    batch_size=4,
    shuffle=True,
    collate_fn=collate_fn
)

val_loader = DataLoader(
    val_dataset,
    batch_size=4,
    shuffle=False,
    collate_fn=collate_fn
)

# ================================
# 6. Load Faster R-CNN Model
# ================================
from torchvision.models.detection import fasterrcnn_resnet50_fpn

model = fasterrcnn_resnet50_fpn(weights="DEFAULT")

num_classes = 3  # Healthy_Leaf + Late_Blight

in_features = model.roi_heads.box_predictor.cls_score.in_features
model.roi_heads.box_predictor = torchvision.models.detection.faster_rcnn.FastRCNNPredictor(
    in_features, num_classes
)

# ================================
# 7. Device (CUDA)
# ================================
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Using device:", device)

model.to(device)

# ================================
# 8. Optimizer
# ================================
optimizer = optim.SGD(
    model.parameters(),
    lr=0.005,
    momentum=0.9,
    weight_decay=0.0005
)

# ================================
# 9. Training Loop
# ================================
import time

EPOCHS = 50

optimizer = torch.optim.SGD(
    model.parameters(),
    lr=0.005,
    momentum=0.9,
    weight_decay=0.0005
)

scheduler = torch.optim.lr_scheduler.StepLR(
    optimizer,
    step_size=15,
    gamma=0.1
)

for epoch in range(1, EPOCHS + 1):
    model.train()
    total_loss = 0
    valid_batches = 0   # ✅ track only valid batches

    t0 = time.time()

    for images, targets in train_loader:

        # 🚨 skip empty batches
        if len(images) == 0:
            continue

        images  = [img.to(device) for img in images]
        targets = [{k: v.to(device) for k, v in t.items()} for t in targets]

        loss_dict = model(images, targets)
        loss      = sum(loss_dict.values())

        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        total_loss += loss.item()
        valid_batches += 1

    scheduler.step()

    # 🚨 avoid division by zero
    avg_loss = total_loss / valid_batches if valid_batches > 0 else 0

    elapsed  = time.time() - t0

    print(f"Epoch [{epoch:02d}/{EPOCHS}]  Loss: {avg_loss:.4f}  Time: {elapsed:.1f}s")

print("\n✅ Training complete!")
# Out:
# ...
# loading annotations into memory...
# Done (t=0.02s)
# creating index...
# index created!
# loading annotations into memory...
# Done (t=0.00s)
# creating index...
# index created!
# Using device: cuda
# ---------------------------------------------------------------------------
# AcceleratorError                          Traceback (most recent call last)
# /tmp/ipykernel_21371/110090651.py in <cell line: 0>()
#      99 print("Using device:", device)
#     100
# --> 101 model.to(device)
#     102
#     103 # ================================
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py in to(self, *args, **kwargs)
#    1382                     raise
#    1383
# -> 1384         return self._apply(convert)
#    1385
#    1386     def register_full_backward_pre_hook(
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py in _apply(self, fn, recurse)
#     932         if recurse:
#     933             for module in self.children():
# ...
